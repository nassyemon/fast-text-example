# %%
import MeCab
import re
from typing import Callable, Iterable, List, Set, Dict, Tuple, Optional

# %%
chasen = MeCab.Tagger("-Ochasen")

# %%
yomi = MeCab.Tagger("-Oyomi")
re_katakana = re.compile(r'[\u30A1-\u30F4]+')
def get_yomi(text: str) -> str:
    reading = yomi.parse(text)
    kana_readings = re_katakana.findall(reading)
    return "".join(kana_readings)

get_yomi("性格がとても悪い")
# Out:
# ['セイカクガトテモワルイ']
# 'セイカクガトテモワルイ'

# %%
# 表層形\t品詞,品詞細分類1,品詞細分類2,品詞細分類3,活用形,活用型,原形,読み,発音 
def get_yomi(feature: str) -> None or str:
    features = elem.feature.split(",")
    if len(features) < 8:
        return None
    return features[7] # 読み

def is_readable(elem: Dict) -> bool:
    if "feature" not in elem or type(feature) != str:
        return False
    features = elem.feature.split(",")
    if len(features) < 8:
        return False
    yomi = features[7] # 読み
    return True if re_katakanafullmatch(yomi) else False

def get_reading(text: str) -> str:
    node = chasen.parseToNode(text)
    node_list = []
    while node:
        node_list += [node]
        node = node.next
    yomi_list = map(get_yomi, node_list)
    display([*yomi_list])

get_reading("性格")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-075946574f94> in <module>
#      23     display([*yomi_list])
#      24
# ---> 25 get_reading("性格")
#
# <ipython-input-64-075946574f94> in get_reading(text)
#      19     node_list = []
#      20     while node:
# ---> 21         node_list += [node]
#      22     yomi_list = map(get_yomi, node_list)
#      23     display([*yomi_list])
#
# KeyboardInterrupt:

# %%
#
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-9f1b0463e161> in <module>
# ----> 1 print([*chasen.parseToNode('性格')])
#
# TypeError: 'MeCab.Node' object is not iterable
